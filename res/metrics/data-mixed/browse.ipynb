# %%
import pandas as pd

# %%
df = pd.read_csv('classification.csv')

# %%
df.sort_values(by='prec')
# Out:
#        cell_line       acc      prec    recall        f1   roc_auc     kappa
# 33       NCIH460  0.952410  0.649635  0.741667  0.692607  0.855249  0.666938
# 15        NCIH23  0.984786  0.666667  0.731707  0.697674  0.861357  0.689889
# 2         HCT116  0.966647  0.673077  0.466667  0.551181  0.728131  0.534450
# 1   UWB1289BRCA1  0.979518  0.711111  0.603774  0.653061  0.797842  0.642581
# 14         LNCAP  0.939157  0.724138  0.819512  0.768879  0.887763  0.734000
# 35         SW837  0.972892  0.731481  0.831579  0.778325  0.906524  0.763951
# 22     COLO320DM  0.981276  0.741379  0.716667  0.728814  0.853785  0.719119
# 37         ZR751  0.965663  0.745455  0.738739  0.742081  0.860331  0.723689
# 34          A375  0.920421  0.748815  0.655602  0.699115  0.809749  0.653495
# 24         SW620  0.968403  0.750000  0.638298  0.689655  0.812957  0.673123
# 10      RPMI7951  0.987349  0.765957  0.782609  0.774194  0.887897  0.767687
# ...
